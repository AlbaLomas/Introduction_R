# %% [markdown]
# # R Exam
#
# Gross domestic product (GDP) is a monetary measure of the market value of all the final goods and services produced in a specific time period. In spanish is called the PIB (Producto Interno Bruto).
# The Human Development Index (HDI) is a statistic composite index of life expectancy, education (Literacy Rate, Gross Enrollment Ratio at different levels and Net Attendance Ratio), and per capita income indicators, which are used to rank countries into four tiers of human development.
#
# Several online websites (among which the spanish wikipedia https://es.wikipedia.org/wiki/%C3%8Dndice_de_desarrollo_humano), have suggested that GDP and HDI are strongly correlated, meaning that the better the country's economy the better the human development of their citizens. Let's try to plot the data for Spain (from 2007) and analyze it.
#
# **FIGURE 1**
# <img src="Fig 1.png">
# **FIGURE 2**
# <img src="Fig 2.png">
# **FIGURE 3**
# <img src="Fig 3.png">
# **FIGURE 4**
# <img src="Fig 4.png">

# %%
x <- read.csv("GDP.csv")
y <- read.csv("HDI.csv")

# %% [markdown]
# - Analyze the file that you have just loaded with head() and str()

# %%
"First 6 lines"
head(x)
str(x)
"Last 6 lines"
tail(x)
# Out:
# [1] "First 6 lines"
#   Province GDP.per.capita CCAA
# 1 Almería  20.873         Andalucía y Extremadura
# 2 Cádiz    18.029         Andalucía y Extremadura
# 3 Córdoba  17.292         Andalucía y Extremadura
# 4 Granada  17.167         Andalucía y Extremadura
# 5 Huelva   18.207         Andalucía y Extremadura
# 6 Jaén     16.433         Andalucía y Extremadura
# 'data.frame':	50 obs. of  3 variables:
#  $ Province      : chr  "Almería" "Cádiz" "Córdoba" "Granada" ...
#  $ GDP.per.capita: num  20.9 18 17.3 17.2 18.2 ...
#  $ CCAA          : chr  "Andalucía y Extremadura" "Andalucía y Extremadura" "Andalucía y Extremadura" "Andalucía y Extremadura" ...
# [1] "Last 6 lines"
#    Province  GDP.per.capita CCAA
# 45 Madrid    31.490         Madrid
# 46 Murcia    19.920         Comunitat Valenciana y Murcia
# 47 Navarra   29.136         País Vasco Navarra y Rioja
# 48 Álava     36.055         País Vasco Navarra y Rioja
# 49 Guipúzcoa 30.731         País Vasco Navarra y Rioja
# 50 Vizcaya   27.705         País Vasco Navarra y Rioja

# %%
"First 6 lines"
head(y)
str(y)
"Last 6 lines"
tail(y)
# Out:
# [1] "First 6 lines"
#   Province HDI
# 1 Cádiz    0.913
# 2 Almería  0.915
# 3 Jaén     0.915
# 4 Huelva   0.917
# 5 Badajoz  0.919
# 6 Córdoba  0.920
# 'data.frame':	50 obs. of  2 variables:
#  $ Province: chr  "Cádiz" "Almería" "Jaén" "Huelva" ...
#  $ HDI     : num  0.913 0.915 0.915 0.917 0.919 0.92 0.92 0.921 0.923 0.924 ...
# [1] "Last 6 lines"
#    Province   HDI
# 45 Valladolid 0.978
# 46 Navarra    0.982
# 47 Madrid     0.983
# 48 Vizcaya    0.988
# 49 Álava      0.990
# 50 Guipúzcoa  0.997

# %% [markdown]
# - Glue together the two data frames by columns (one next to the other) using cbind(). We want the province to match on the same rows, so you need first to sort the rows of the two data frames by Province, using order()

# %%
"Sort GDP by Province"
xo <- x[order(x$Province), ]

"Sort HDI by Province"
yo <- y[order(y$Province), ]
# Out:
# [1] "Sort GDP by Province"
# [1] "Sort HDI by Province"

# %%
new_dataframe <- cbind(xo,yo)
new_dataframe
# Out:
#    Province               GDP.per.capita CCAA
# 48 Álava                  36.055         País Vasco Navarra y Rioja
# 26 Albacete               17.864         Castilla-La Mancha
# 34 Alicante               19.201         Comunitat Valenciana y Murcia
# 1  Almería                20.873         Andalucía y Extremadura
# 12 Asturias               21.634         Asturias y Cantabria
# 16 Ávila                  18.382         Castilla y León
# 37 Badajoz                16.238         Andalucía y Extremadura
# 30 Barcelona              28.069         Cataluña y Islas Baleares
# 17 Burgos                 25.994         Castilla y León
# 38 Cáceres                16.076         Andalucía y Extremadura
# 2  Cádiz                  18.029         Andalucía y Extremadura
# 15 Cantabria              22.390         Asturias y Cantabria
# 35 Castellón              23.832         Comunitat Valenciana y Murcia
# 27 Ciudad Real            19.525         Castilla-La Mancha
# 3  Córdoba                17.292         Andalucía y Extremadura
# 28 Cuenca                 19.570         Castilla-La Mancha
# 31 Gerona                 28.040         Cataluña y Islas Baleares
# 4  Granada                17.167         Andalucía y Extremadura
# 18 Guadalajara            19.857         Castilla y León
# 49 Guipúzcoa              30.731         País Vasco Navarra y Rioja
# 5  Huelva                 18.207         Andalucía y Extremadura
# 9  Huesca                 25.639         Aragon
# 43 Islas Baleares         25.811         Cataluña y Islas Baleares
# 6  Jaén                   16.433         Andalucía y Extremadura
# 39 La Coruña              21.305         Galicia
# 44 La Rioja               25.438         País Vasco Navarra y Rioja
# 13 Las Palmas             20.790         Canarias
# 19 León                   20.172         Castilla y León
# 32 Lérida                 27.828         Cataluña y Islas Baleares
# 40 Lugo                   19.587         Galicia
# 45 Madrid                 31.490         Madrid
# 7  Málaga                 18.193         Andalucía y Extremadura
# 46 Murcia                 19.920         Comunitat Valenciana y Murcia
# 47 Navarra                29.136         País Vasco Navarra y Rioja
# 41 Ourense                18.009         Galicia
# 20 Palencia               24.246         Castilla y León
# 42 Pontevedra             20.542         Galicia
# 21 Salamanca              19.201         Castilla y León
# 14 Santa Cruz de Tenerife 21.333         Canarias
# 22 Segovia                22.996         Castilla y León
# 8  Sevilla                19.689         Andalucía y Extremadura
# 23 Soria                  22.992         Castilla y León
# 33 Tarragona              27.408         Cataluña y Islas Baleares
# 10 Teruel                 24.702         Aragon
# 29 Toledo                 19.251         Castilla-La Mancha
# 36 Valencia               22.538         Comunitat Valenciana y Murcia
# 24 Valladolid             23.947         Castilla y León
# 50 Vizcaya                27.705         País Vasco Navarra y Rioja
# 25 Zamora                 17.952         Castilla y León
# 11 Zaragoza               26.082         Aragon
#    Province               HDI
# 48 Álava                  0.990
# 26 Albacete               0.933
# 34 Alicante               0.930
# 1  Almería                0.915
# 12 Asturias               0.956
# 16 Ávila                  0.952
# 37 Badajoz                0.919
# 30 Barcelona              0.962
# 17 Burgos                 0.972
# 38 Cáceres                0.924
# 2  Cádiz                  0.913
# 15 Cantabria              0.963
# 35 Castellón              0.941
# 27 Ciudad Real            0.923
# 3  Córdoba                0.920
# 28 Cuenca                 0.937
# 31 Gerona                 0.951
# 4  Granada                0.921
# 18 Guadalajara            0.958
# 49 Guipúzcoa              0.997
# 5  Huelva                 0.917
# 9  Huesca                 0.961
# 43 Islas Baleares         0.937
# 6  Jaén                   0.915
# 39 La Coruña              0.959
# 44 La Rioja               0.962
# 13 Las Palmas             0.933
# 19 León                   0.955
# 32 Lérida                 0.958
# 40 Lugo                   0.943
# 45 Madrid                 0.983
# 7  Málaga                 0.920
# 46 Murcia                 0.930
# 47 Navarra                0.982
# 41 Ourense                0.936
# 20 Palencia               0.964
# 42 Pontevedra             0.945
# 21 Salamanca              0.975
# 14 Santa Cruz de Tenerife 0.931
# 22 Segovia                0.960
# 8  Sevilla                0.934
# 23 Soria                  0.957
# 33 Tarragona              0.949
# 10 Teruel                 0.960
# 29 Toledo                 0.933
# 36 Valencia               0.946
# 24 Valladolid             0.978
# 50 Vizcaya                0.988
# 25 Zamora                 0.959
# 11 Zaragoza               0.968

# %% [markdown]
# The new data frame will contain two columns names "Province". remove one of the columns

# %%
df_new <- new_dataframe[,-4]
df_new
# Out:
#    Province               GDP.per.capita CCAA                          HDI
# 48 Álava                  36.055         País Vasco Navarra y Rioja    0.990
# 26 Albacete               17.864         Castilla-La Mancha            0.933
# 34 Alicante               19.201         Comunitat Valenciana y Murcia 0.930
# 1  Almería                20.873         Andalucía y Extremadura       0.915
# 12 Asturias               21.634         Asturias y Cantabria          0.956
# 16 Ávila                  18.382         Castilla y León               0.952
# 37 Badajoz                16.238         Andalucía y Extremadura       0.919
# 30 Barcelona              28.069         Cataluña y Islas Baleares     0.962
# 17 Burgos                 25.994         Castilla y León               0.972
# 38 Cáceres                16.076         Andalucía y Extremadura       0.924
# 2  Cádiz                  18.029         Andalucía y Extremadura       0.913
# 15 Cantabria              22.390         Asturias y Cantabria          0.963
# 35 Castellón              23.832         Comunitat Valenciana y Murcia 0.941
# 27 Ciudad Real            19.525         Castilla-La Mancha            0.923
# 3  Córdoba                17.292         Andalucía y Extremadura       0.920
# 28 Cuenca                 19.570         Castilla-La Mancha            0.937
# 31 Gerona                 28.040         Cataluña y Islas Baleares     0.951
# 4  Granada                17.167         Andalucía y Extremadura       0.921
# 18 Guadalajara            19.857         Castilla y León               0.958
# 49 Guipúzcoa              30.731         País Vasco Navarra y Rioja    0.997
# 5  Huelva                 18.207         Andalucía y Extremadura       0.917
# 9  Huesca                 25.639         Aragon                        0.961
# 43 Islas Baleares         25.811         Cataluña y Islas Baleares     0.937
# 6  Jaén                   16.433         Andalucía y Extremadura       0.915
# 39 La Coruña              21.305         Galicia                       0.959
# 44 La Rioja               25.438         País Vasco Navarra y Rioja    0.962
# 13 Las Palmas             20.790         Canarias                      0.933
# 19 León                   20.172         Castilla y León               0.955
# 32 Lérida                 27.828         Cataluña y Islas Baleares     0.958
# 40 Lugo                   19.587         Galicia                       0.943
# 45 Madrid                 31.490         Madrid                        0.983
# 7  Málaga                 18.193         Andalucía y Extremadura       0.920
# 46 Murcia                 19.920         Comunitat Valenciana y Murcia 0.930
# 47 Navarra                29.136         País Vasco Navarra y Rioja    0.982
# 41 Ourense                18.009         Galicia                       0.936
# 20 Palencia               24.246         Castilla y León               0.964
# 42 Pontevedra             20.542         Galicia                       0.945
# 21 Salamanca              19.201         Castilla y León               0.975
# 14 Santa Cruz de Tenerife 21.333         Canarias                      0.931
# 22 Segovia                22.996         Castilla y León               0.960
# 8  Sevilla                19.689         Andalucía y Extremadura       0.934
# 23 Soria                  22.992         Castilla y León               0.957
# 33 Tarragona              27.408         Cataluña y Islas Baleares     0.949
# 10 Teruel                 24.702         Aragon                        0.960
# 29 Toledo                 19.251         Castilla-La Mancha            0.933
# 36 Valencia               22.538         Comunitat Valenciana y Murcia 0.946
# 24 Valladolid             23.947         Castilla y León               0.978
# 50 Vizcaya                27.705         País Vasco Navarra y Rioja    0.988
# 25 Zamora                 17.952         Castilla y León               0.959
# 11 Zaragoza               26.082         Aragon                        0.968

# %% [markdown]
# Check that everything is fine with head() and tail(). The final data frame should have 4 columns: Province GDP.per.capita, CCAA and HDI. With each province matching its CCAA. (Fig, 1)

# %%
head(df_new) #This command shows that the first six lines are equal to the Fig 1.
# Out:
#    Province GDP.per.capita CCAA                          HDI
# 48 Álava    36.055         País Vasco Navarra y Rioja    0.990
# 26 Albacete 17.864         Castilla-La Mancha            0.933
# 34 Alicante 19.201         Comunitat Valenciana y Murcia 0.930
# 1  Almería  20.873         Andalucía y Extremadura       0.915
# 12 Asturias 21.634         Asturias y Cantabria          0.956
# 16 Ávila    18.382         Castilla y León               0.952

# %%
tail(df_new)
# Out:
#    Province   GDP.per.capita CCAA                          HDI
# 29 Toledo     19.251         Castilla-La Mancha            0.933
# 36 Valencia   22.538         Comunitat Valenciana y Murcia 0.946
# 24 Valladolid 23.947         Castilla y León               0.978
# 50 Vizcaya    27.705         País Vasco Navarra y Rioja    0.988
# 25 Zamora     17.952         Castilla y León               0.959
# 11 Zaragoza   26.082         Aragon                        0.968

# %% [markdown]
# - Create scatterplot of text using geom_point(). Plot the GDP.per.capita (x-axis) against the HDI (y-axis). Color the points by CCAA (use color=CCAA inside the aes() function of geom_point).

# %%
library(ggplot2)
ggplot(df_new, aes(x=GDP.per.capita, y=HDI, color=CCAA)) +
geom_point(size = 10) + theme(text = element_text(family = "Arial", size = 35, face = "bold"))
# Out:
# plot without title

# %% [markdown]
# - Do the same but use geom_text(). Specify as labels the names of the provinces, using aes(label=Province) inside geom_text. Color by CCAA. Also specify check_overlap=T so that the names do not overlap, if you want. (Fig, 2)

# %%
ggplot(df_new, aes(x=GDP.per.capita, y=HDI, color=CCAA)) +
geom_text(aes(label=Province), check_overlap=T, size = 8) + 
    theme(text = element_text(family = "Arial", size = 20, face = "bold"))
# Allow the plot to be bigger
options(repr.plot.width = 20, repr.plot.height = 15, repr.plot.res = 50)
# Out:
# plot without title

# %% [markdown]
# - Calculate the mean and standard deviation of GDP and HDI, by CCAA, using aggregate ().

# %%
mean_HDI <- aggregate(df_new$HDI, list(df_new$CCAA), mean)
colnames(mean_HDI) <- c("CCAA", "Mean HDI")

# %%
mean_HDI
# Out:
#    CCAA                          Mean HDI
# 1  Andalucía y Extremadura       0.91980
# 2  Aragon                        0.96300
# 3  Asturias y Cantabria          0.95950
# 4  Canarias                      0.93200
# 5  Castilla y León               0.96300
# 6  Castilla-La Mancha            0.93150
# 7  Cataluña y Islas Baleares     0.95140
# 8  Comunitat Valenciana y Murcia 0.93675
# 9  Galicia                       0.94575
# 10 Madrid                        0.98300
# 11 País Vasco Navarra y Rioja    0.98380

# %%
mean_GDP <- aggregate(df_new$GDP.per.capita, list(df_new$CCAA), mean)
colnames(mean_GDP) <- c("CCAA", "Mean GDP")

# %%
mean_GDP
# Out:
#    CCAA                          Mean GDP
# 1  Andalucía y Extremadura       17.81970
# 2  Aragon                        25.47433
# 3  Asturias y Cantabria          22.01200
# 4  Canarias                      21.06150
# 5  Castilla y León               21.57390
# 6  Castilla-La Mancha            19.05250
# 7  Cataluña y Islas Baleares     27.43120
# 8  Comunitat Valenciana y Murcia 21.37275
# 9  Galicia                       19.86075
# 10 Madrid                        31.49000
# 11 País Vasco Navarra y Rioja    29.81300

# %%
sd_GDP <- aggregate(df_new$GDP.per.capita, list(df_new$CCAA), sd)
colnames(sd_GDP) <- c("CCAA", "SD GDP")

# %%
sd_GDP
# Out:
#    CCAA                          SD GDP
# 1  Andalucía y Extremadura       1.5391112
# 2  Aragon                        0.7045824
# 3  Asturias y Cantabria          0.5345727
# 4  Canarias                      0.3839590
# 5  Castilla y León               2.7926986
# 6  Castilla-La Mancha            0.8047768
# 7  Cataluña y Islas Baleares     0.9434594
# 8  Comunitat Valenciana y Murcia 2.1781260
# 9  Galicia                       1.4205488
# 10 Madrid                               NA
# 11 País Vasco Navarra y Rioja    3.9952442

# %%
sd_HDI <- aggregate(df_new$HDI, list(df_new$CCAA), sd)
colnames(sd_HDI) <- c("CCAA", "SD HDI")

# %%
sd_HDI
# Out:
#    CCAA                          SD HDI
# 1  Andalucía y Extremadura       0.005977736
# 2  Aragon                        0.004358899
# 3  Asturias y Cantabria          0.004949747
# 4  Canarias                      0.001414214
# 5  Castilla y León               0.008956686
# 6  Castilla-La Mancha            0.005972158
# 7  Cataluña y Islas Baleares     0.009607289
# 8  Comunitat Valenciana y Murcia 0.008057088
# 9  Galicia                       0.009639329
# 10 Madrid                                 NA
# 11 País Vasco Navarra y Rioja    0.013311649

# %% [markdown]
# - Create a new data frame where you put each CCAA with the corresponding mean GDP, mean HDI, stdev GDP and stdev HDI

# %%
df_mean<- cbind(mean_GDP, mean_HDI)

# %%
df_mean <- df_mean[,-3]

# %%
df_mean
# Out:
#    CCAA                          Mean GDP Mean HDI
# 1  Andalucía y Extremadura       17.81970 0.91980
# 2  Aragon                        25.47433 0.96300
# 3  Asturias y Cantabria          22.01200 0.95950
# 4  Canarias                      21.06150 0.93200
# 5  Castilla y León               21.57390 0.96300
# 6  Castilla-La Mancha            19.05250 0.93150
# 7  Cataluña y Islas Baleares     27.43120 0.95140
# 8  Comunitat Valenciana y Murcia 21.37275 0.93675
# 9  Galicia                       19.86075 0.94575
# 10 Madrid                        31.49000 0.98300
# 11 País Vasco Navarra y Rioja    29.81300 0.98380

# %%
df_SD<- cbind(sd_GDP, sd_HDI)

# %%
df_SD <- df_SD[,-3]

# %%
df_SD
# Out:
#    CCAA                          SD GDP    SD HDI
# 1  Andalucía y Extremadura       1.5391112 0.005977736
# 2  Aragon                        0.7045824 0.004358899
# 3  Asturias y Cantabria          0.5345727 0.004949747
# 4  Canarias                      0.3839590 0.001414214
# 5  Castilla y León               2.7926986 0.008956686
# 6  Castilla-La Mancha            0.8047768 0.005972158
# 7  Cataluña y Islas Baleares     0.9434594 0.009607289
# 8  Comunitat Valenciana y Murcia 2.1781260 0.008057088
# 9  Galicia                       1.4205488 0.009639329
# 10 Madrid                               NA          NA
# 11 País Vasco Navarra y Rioja    3.9952442 0.013311649

# %%
df_mean_sd <- cbind(df_mean, df_SD)

# %%
df_mean_sd <- df_mean_sd[,-4]

# %%
df_mean_sd
# Out:
#    CCAA                          Mean GDP Mean HDI SD GDP    SD HDI
# 1  Andalucía y Extremadura       17.81970 0.91980  1.5391112 0.005977736
# 2  Aragon                        25.47433 0.96300  0.7045824 0.004358899
# 3  Asturias y Cantabria          22.01200 0.95950  0.5345727 0.004949747
# 4  Canarias                      21.06150 0.93200  0.3839590 0.001414214
# 5  Castilla y León               21.57390 0.96300  2.7926986 0.008956686
# 6  Castilla-La Mancha            19.05250 0.93150  0.8047768 0.005972158
# 7  Cataluña y Islas Baleares     27.43120 0.95140  0.9434594 0.009607289
# 8  Comunitat Valenciana y Murcia 21.37275 0.93675  2.1781260 0.008057088
# 9  Galicia                       19.86075 0.94575  1.4205488 0.009639329
# 10 Madrid                        31.49000 0.98300         NA          NA
# 11 País Vasco Navarra y Rioja    29.81300 0.98380  3.9952442 0.013311649

# %% [markdown]
# - Madrid is a single province CCAA, so you will see that its standar deviation is NA. Replace those NAs with zeros, using is.na(). (Fig, 3)

# %%
df_mean_sd[is.na(df_mean_sd)] = 0

# %%
df_mean_sd
# Out:
#    CCAA                          Mean GDP Mean HDI SD GDP    SD HDI
# 1  Andalucía y Extremadura       17.81970 0.91980  1.5391112 0.005977736
# 2  Aragon                        25.47433 0.96300  0.7045824 0.004358899
# 3  Asturias y Cantabria          22.01200 0.95950  0.5345727 0.004949747
# 4  Canarias                      21.06150 0.93200  0.3839590 0.001414214
# 5  Castilla y León               21.57390 0.96300  2.7926986 0.008956686
# 6  Castilla-La Mancha            19.05250 0.93150  0.8047768 0.005972158
# 7  Cataluña y Islas Baleares     27.43120 0.95140  0.9434594 0.009607289
# 8  Comunitat Valenciana y Murcia 21.37275 0.93675  2.1781260 0.008057088
# 9  Galicia                       19.86075 0.94575  1.4205488 0.009639329
# 10 Madrid                        31.49000 0.98300  0.0000000 0.000000000
# 11 País Vasco Navarra y Rioja    29.81300 0.98380  3.9952442 0.013311649

# %% [markdown]
# - Plot again the original scatterplot with geom_point and color by CCAA.

# %%
library(ggplot2)
ggplot(df_new, aes(x=GDP.per.capita, y=HDI, color=CCAA)) +
geom_point(size=7) + theme(text = element_text(family = "Arial", size = 35, face = "bold"))
# Out:
# plot without title

# %% [markdown]
# - Add over this plot another scatterplot using the new data frame (specify data=...), plotting the mean GDP against the mean HDI by CCAA that you have calculated with aggregate. These points should appear somewhere in the middle of their corresponding provinces.

# %%
ggplot(df_new, aes(x=GDP.per.capita, y=HDI, color=CCAA)) +
geom_point(size=7) + theme(text = element_text(family = "Arial", size = 35, face = "bold")) + geom_point(data=df_mean_sd, x=df_mean_sd[,2], y=df_mean_sd[,3], size=20)
# Out:
# plot without title

# %% [markdown]
# - Add also vertical and horizontal error bars to express the variablity for each CCAA (with geom_errorbar and geom_errorbarh). For geom_errorbar() you have to specify the aestetic paramters x, y, ymin and ymax. For geom_errorbarh you have to specify the aestetic paramters x, y, xmin and xmax.

# %%
ggplot() + geom_point(data = df_new, aes(x=df_new[,2], y=df_new[,4], color=CCAA),  size=10) + theme(text = element_text(family = "Arial", size = 40, face = "bold")) + geom_point(data=df_mean_sd, x=df_mean_sd[,2], y=df_mean_sd[,3], size=10) +  
    geom_errorbar(data = df_mean_sd, aes(x = df_mean_sd[,2], ymin = df_mean_sd[,3] - df_mean_sd[,5], ymax = df_mean_sd[,3] + df_mean_sd[,5])) + 
    geom_errorbarh(data = df_mean_sd, aes(y = df_mean_sd[,3], xmin = df_mean_sd[,2] - df_mean_sd[,4], xmax = df_mean_sd[,2] + df_mean_sd[,4])) +
 labs(x = "GDP per capita",y = "HDI")
# Out:
# plot without title

# %% [markdown]
# - Finally, add the name of each CCAA on the plot with geom_label(). You can add the parameters  hjust=1, vjust=1 to move the labels a little bit so they don't overlap the points (Fig, 4)

# %%
ggplot() + geom_point(data = df_new, aes(x=df_new[,2], y=df_new[,4], color=CCAA),  size=10) + theme(text = element_text(family = "Arial", size = 25, face = "bold")) + 
    geom_point(data=df_mean_sd, x=df_mean_sd[,2], y=df_mean_sd[,3], size=10) +  
    geom_errorbar(data = df_mean_sd, aes(x = df_mean_sd[,2], ymin = df_mean_sd[,3] - df_mean_sd[,5], ymax = df_mean_sd[,3] + df_mean_sd[,5])) + 
    geom_errorbarh(data = df_mean_sd, aes(y = df_mean_sd[,3], xmin = df_mean_sd[,2] - df_mean_sd[,4], xmax = df_mean_sd[,2] + df_mean_sd[,4])) +
    geom_label(data=df_mean_sd, x=df_mean_sd[,2], y=df_mean_sd[,3], label = df_mean_sd[,1], size = 9, hjust=1, vjust=1) + labs(x = "GDP per capita",y = "HDI")
# Out:
# plot without title

# %% [markdown]
# - (Optional) It looks like that GDP is strongly correlated with HDI (the dots follow a straight line).However, you should know that the formula for HDI is (roughly) LifeExpectancy + EducationIndex + GDP.
# Do you think there is something weird? Do you still think that concluding, by simply looking at the chart, that increasing the GDP you can increase the human development of their citizens (or viceversa)? If not, why? Should we maybe compare GDP and HDI in a different way?
